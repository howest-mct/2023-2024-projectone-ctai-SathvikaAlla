# %%
# !pip install ultralytics==8.0.196
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="jPcxyBKHadNL8MvyFl51")
project = rf.workspace("howest2").project("skin-diseases-2")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to skin-diseases-2-7 in yolov8:: 100%|██████████| 4621/4621 [00:00<00:00, 6475.75it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8s")
results = model.train(epochs=300, patience=100, data=f"{dataset.location}/data.yaml", imgsz=480, batch=32)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 252MB/s]
# New https://pypi.org/project/ultralytics/8.2.28 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
version.deploy("yolov8", "runs/detect/train")
# Out:
# View the status of your deployment at: https://app.roboflow.com/howest2/skin-diseases-2/7
