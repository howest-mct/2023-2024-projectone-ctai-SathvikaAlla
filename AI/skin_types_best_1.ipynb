# %%
# !pip install ultralytics==8.0.196
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 4.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="1rAyMTikDnt3YhC7Wzzy")
project = rf.workspace("howest-koykd").project("skin-types-2")
version = project.version(5)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to skin-types-2-5 in folder:: 100%|██████████| 1197/1197 [00:00<00:00, 6543.36it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8s-cls.pt")
model.train(epochs=50, data=f"{dataset.location}", imgsz=640, batch=32 )
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.predict("/content/close-young-man-pointing-acne-260nw-2190866601.webp")
# Out:
# image 1/1 /content/close-young-man-pointing-acne-260nw-2190866601.webp: 640x640 oily 0.97, normal 0.02, dry 0.00, 7.8ms
# Speed: 8.8ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
#  names: {0: 'dry', 1: 'normal', 2: 'oily'}
#  orig_img: array([[[156, 161, 192],
#          [152, 158, 189],
#          [150, 156, 187],
#          ...,
#          [250, 239, 230],
#          [250, 239, 230],
#          [250, 239, 230]],
#
#         [[150, 158, 189],
#          [149, 157, 188],
#          [145, 152, 183],
#          ...,
#          [250, 240, 228],
#          [250, 239, 230],
#          [250, 239, 230]],
#
#         [[139, 149, 181],
#          [140, 150, 182],
#          [132, 142, 174],
#          ...,
#          [250, 241, 226],
#          [250, 240, 228],
#          [250, 240, 228]],
#
#         ...,
#
#         [[255, 255, 255],
# ...
